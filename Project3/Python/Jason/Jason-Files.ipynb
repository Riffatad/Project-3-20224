# %%
import os
import csv
import json
import re
from collections import defaultdict
import pandas as pd
import sqlalchemy as sa
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# Load the CSV file
file_path = 'elec-vehicle.csv'

try:
    data = pd.read_csv(file_path)
    print("File loaded successfully!")
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
    exit()
except pd.errors.ParserError:
    print("Error: Failed to parse the CSV file. Check its format.")
    exit()

filtered_data = data[
    (data['Model Year'].between(2019, 2023)) &  # Include 2019 to 2023
    (data['Electric Vehicle Type'] == "Battery Electric Vehicle (BEV)") &  # Only BEVs
    (data['Electric Range'] > 0)  # Exclude zero or missing Electric Range
]

# Clean the data to ensure it's JSON-serializable
cleaned_data = filtered_data.fillna("").applymap(
    lambda x: x.strip() if isinstance(x, str) else x
)

# Save the data to a single JSON array file (no limit on records)
output_file_path = 'filtered_battery_vehicles_2023.json'
cleaned_data.to_json(output_file_path, orient='records', indent=4)  # Standard JSON format

print(f"Filtered data has been saved to: {output_file_path}")
# Out:
# File loaded successfully!
# Filtered data has been saved to: filtered_battery_vehicles_2023.json
# C:\Users\riffa\AppData\Local\Temp\ipykernel_28760\3468943865.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   cleaned_data = filtered_data.fillna("").applymap(

# %% [raw]
# # Load the CSV file
# file_path = 'elec-vehicle.csv'
# data = pd.read_csv(file_path)
#
# # Filter for battery-operated vehicles with non-zero electric range
# filtered_data = data[
#     (data['Electric Vehicle Type'] == "Battery Electric Vehicle (BEV)") &
#     (data['Electric Range'] > 0)
# ]
#
# # Limit to 20,000 records
# filtered_data_limited = filtered_data.head(20000)
#
# # Clean the data to ensure it's JSON-serializable
# cleaned_data = filtered_data_limited.fillna("").applymap(
#     lambda x: x.strip() if isinstance(x, str) else x
# )
#
# # Save the data to a single JSON array file
# output_file_path = 'filtered_battery_vehicles_cleaned.json'
# cleaned_data.to_json(output_file_path, orient='records', indent=4)  # Standard JSON format
#
# print(f"Filtered data has been saved to: {output_file_path}")

# %% [raw]
# # Load the CSV file created into a Pandas DataFrame
#
# engine = sa.create_engine('postgresql://postgres:postgre@localhost:5432/Project3DB')
#
# # Create a connection object
# conn = engine.connect()
#
# # Execute a query and fetch results into a DataFrame
# Ev_data_df = pd.read_sql('SELECT * FROM "EV_DATA"', conn)
#
# #valid_counties_df = pd.read_sql('SELECT distinct "County" FROM "EV_DATA"', conn)
#
# # Close the connection
# conn.close()
#
# Ev_data_df.to_json("output.json", orient="records", indent=4)
#
#
#
# # Close the connection
# connection.close()
#
# print("Data exported to output.json")

# %% [raw]
# # List of valid Washington counties
#
# #valid_counties = valid_counties_df.to_dict(orient="records")
#
# # Input and output file paths
# input_file = 'output.json'
# output_file = 'aggregate_ev_population_with_location.json'
#
# # Load the input JSON file
# with open(input_file, 'r') as f:
#     data = json.load(f)
#
#
# # Initialize storage for county aggregation
# county_data = defaultdict(lambda: {"EVPopulation": 0, "Latitude": None, "Longitude": None})
#
#
# # Process each entry
# for entry in data:
#
#     county = entry.get("County")
#     vehicle_location = entry.get("Vehicle Location")
#     model_year = entry.get("Model Year")
#
#     # Normalize the county name (strip spaces and lowercase)
#     normalized_county = county.strip().lower().title()
#
#
#     # Skip if county is not in the list of valid Washington counties
#     #if normalized_county not in valid_counties:
#     #    display(normalized_county)
#     #    print("Not in the list")
#     #    continue
#     #Print("IN VALID COUNTY")
#
#     # Increment EV population count for the county
#     county_data[normalized_county]["EVPopulation"] += 1
#
#     # Extract coordinates from "POINT (longitude latitude)"
#     if county_data[normalized_county]["Latitude"] is None and county_data[normalized_county]["Longitude"] is None:
#         match = re.search(r"POINT \(([-\d.]+) ([-\d.]+)\)", vehicle_location)
#         if match:
#             longitude, latitude = map(float, match.groups())
#             county_data[normalized_county]["Latitude"] = latitude
#             county_data[normalized_county]["Longitude"] = longitude
#
# # Convert to list of dictionaries
# aggregated_data = [
#     {"County": county, "EVPopulation": values["EVPopulation"],
#      "Latitude": values["Latitude"], "Longitude": values["Longitude"]}
#     for county, values in county_data.items()
# ]
#
#
# # Limit the data to 15,000 entries (if there are more than 15,000)
# # aggregated_data = aggregated_data[:15000]
#
# # Save the aggregated data to a new JSON file
# with open(output_file, 'w') as f:
#     json.dump(aggregated_data, f, indent=4)
#
# print(f"Aggregated data saved to {output_file}")
